# %% [markdown]
# <a href="https://colab.research.google.com/github/pmj-chosim/AIstudy/blob/main/%EB%A6%BF%EC%A7%80%20%EB%9D%BC%EC%8F%98%203/24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d8926c19-4b03-480d-8216-a840f687b813" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d8926c19-4b03-480d-8216-a840f687b813">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1817db1b-1dd1-49a2-b234-aa59dabb8523" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1817db1b-1dd1-49a2-b234-aa59dabb8523">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1bc40d37-260c-4dfd-ab9a-8b87567ef044" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1bc40d37-260c-4dfd-ab9a-8b87567ef044">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
trainfile = pd.read_csv("train[1].csv")

# %%
print(trainfile)
# Out:
#             ID      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  \
# 0    TRAIN_000   0.04819  80.0   3.64   0.0  0.392  6.108   32.0  9.2203
# 1    TRAIN_001   1.42502   0.0  19.58   0.0  0.871  6.510  100.0  1.7659
# 2    TRAIN_002   0.01778  95.0   1.47   0.0  0.403  7.135   13.9  7.6534
# 3    TRAIN_003   9.51363   0.0  18.10   0.0  0.713  6.728   94.1  2.4961
# 4    TRAIN_004   1.65660   0.0  19.58   0.0  0.871  6.122   97.3  1.6180
# ..         ...       ...   ...    ...   ...    ...    ...    ...     ...
# 450  TRAIN_450   0.33983  22.0   5.86   0.0  0.431  6.108   34.9  8.0555
# 451  TRAIN_451   3.83684   0.0  18.10   0.0  0.770  6.251   91.1  2.2955
# 452  TRAIN_452   0.20746   0.0  27.74   0.0  0.609  5.093   98.0  1.8226
# 453  TRAIN_453   0.09299   0.0  25.65   0.0  0.581  5.961   92.9  2.0869
# 454  TRAIN_454  25.94060   0.0  18.10   0.0  0.679  5.304   89.1  1.6475
#
#       RAD    TAX  PTRATIO       B  LSTAT  MEDV
# ...

# %%
targetfile=pd.read_csv("sample_submission[1].csv")

# %%
testfile=pd.read_csv("test[1].csv")

# %%
X = trainfile.drop(columns=['ID', 'MEDV'])
y = trainfile['MEDV']

# %%
testfile = testfile.drop(columns=['ID'])

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


X_train, X_test,y_train, y_test = train_test_split(X, y, test_size=0.2)


ridge_model = Ridge(alpha=1.0)


ridge_model.fit(X_train, y_train)


y_pred = ridge_model.predict(X_test)


score = ridge_model.score(X_train, y_train)
print(f"R-squared score: {score:.2f}")

score = ridge_model.score(X_test, y_test)
print(f"R-squared score: {score:.2f}")
# Out:
# R-squared score: 0.73
# R-squared score: 0.76

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


lasso_model = Lasso(alpha=1.0)

lasso_model.fit(X_train, y_train)

y_pred = lasso_model.predict(X_test)

score = lasso_model.score(X_train, y_train)
print(f"R-squared score: {score:.2f}")

score = lasso_model.score(X_test, y_test)
print(f"R-squared score: {score:.2f}")
# Out:
# R-squared score: 0.66
# R-squared score: 0.61
